# %%
from pathlib import Path

import sys
sys.path.insert(0, str(Path('..').resolve()))

from bella.parsers import semeval_14, semeval_15_16
from bella.dataloaders import TargetAugmentation, LeftRightAugmentSequence, LeftRightTargetSequence
from bella import error_analysis
# Out:
# Using TensorFlow backend.

# %%
rest_sem_dir = Path('..', '..', 'aspect datasets', 'semeval_2014')
rest_train = semeval_14(Path(rest_sem_dir, 'restaurants_train.xml'))
rest_test = semeval_14(Path(rest_sem_dir, 'restaurants_test.xml'))

# %%
same_one = error_analysis.same_one_sentiment(rest_test, rest_train, True)
same_multi = error_analysis.same_multi_sentiment(rest_test, rest_train, True)
sim = error_analysis.similar_sentiment(rest_test, rest_train, True)
diff = error_analysis.different_sentiment(rest_test, rest_train, True)
unk = error_analysis.unknown_targets(rest_test, rest_train, True)
all_t = [same_one, same_multi, sim, diff, unk]
all_t_len = [len(t) for t in all_t]
sum(all_t_len)
# Out:
# 1120

# %%
len(rest_test)
# Out:
# 1120

# %%
rest_test.name
# Out:
# 'TargetCollection'

# %%
rest_train['restaurants_train31210']
# Out:
# Target({'spans': [(8, 13)], 'target': 'staff', 'text': 'But the staff was so horrible to us.', 'sentiment': -1, 'sentence_id': 'restaurants_train3121'})

# %%
rest_15_sem_dir = Path('/home/andrew/Documents/ABSA15_RestaurantsTrain')
rest_15_train = semeval_15_16(Path(rest_15_sem_dir, 'ABSA-15_Restaurants_Train_Final.xml'), 
                              raise_error_no_category=True, sep_15_from_14=True)

# %%
rest_train_targets = rest_train.target_set()
category_targets, _ = rest_15_train.categories_targets()
target_to_targets = rest_train.target_targets(rest_train_targets, category_targets)
# Out:
# Filtered 1 categories which are:
# FOOD#GENERAL

# %%
len(target_to_targets)
# Out:
# 407

# %%
t = TargetAugmentation(target_to_targets, 0.5)

# %%
rest_train_fp, rest_dev_fp = rest_train.to_json_file(['restaurants train', 'restaurants dev'], 
                                                     0.2, cache=False, random_state=42)
example = LeftRightTargetSequence(rest_train_fp, 5, str.split, transformers=[t])

# %%
rest_train_fp, rest_dev_fp = rest_train.to_json_file(['restaurants train', 'restaurants dev'], 
                                                     0.2, cache=False, random_state=42)

example = TargetAugmentSequence(rest_train_fp, 5, str.split, transformers=[t])

# %%
example[1]
# Out:
# yes
# yes
# yes
# ([['Good premium sake.',
#    'Good chow fun and chow see.',
#    'Great proprietor.',
#    'Taxan delicious!',
#    'Good food.'],
#   ['premium sake', 'chow fun and chow see', 'proprietor', 'Taxan', 'food']],
#  [1, 1, 1, 1, 1])

# %%
example1 = TargetAugmentSequence(rest_train_fp, 5, str.split, transformers=[ts])

# %%
example1[1]
# Out:
# ([['Good drink.',
#    'Good food.',
#    'Great staff.',
#    'Taxan delicious!',
#    'Good food.'],
#   ['drink', 'food', 'staff', 'Taxan', 'food']],
#  [1, 1, 1, 1, 1])

# %%
example
# Out:
# {'spans': [(57, 61)],
#  'target': 'food',
#  'text': "To be completely fair, the only redeeming factor was the food, which was above average, but couldn't make up for all the other deficiencies of Teodora.",
#  'sentiment': 1,
#  'sentence_id': 'restaurants_train2777',
#  'target_id': 'restaurants_train27770'}

# %%
b = t(example)
b
# Out:
# 0.5460352407716254
# 1
# yes
# {'spans': [(57, 67)],
#  'target': 'anti-pasta',
#  'text': "To be completely fair, the only redeeming factor was the anti-pasta, which was above average, but couldn't make up for all the other deficiencies of Teodora.",
#  'sentiment': 1,
#  'sentence_id': 'restaurants_train2777',
#  'target_id': 'restaurants_train27770'}

# %%
Object
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-83cf31368451> in <module>
# ----> 1 Object
#
# NameError: name 'Object' is not defined

# %%
c
# Out:
# {'spans': [(57, 62)],
#  'target_id': 'restaurants_train27770',
#  'target': 'sushi',
#  'text': "To be completely fair, the only redeeming factor was the sushi, which was above average, but couldn't make up for all the other deficiencies of Teodora.",
#  'sentiment': 1,
#  'sentence_id': 'restaurants_train2777'}

# %%
c = []
for t in rest_train_targets:
    if t not in target_to_targets:
        c.append(t)
sorted(c)
# Out:
# ["'gourmet' Indian cuisine",
#  '2-person table',
#  'AC',
#  'AT MOSHPHERE',
#  "Abby's treasure",
#  'American Chinese food',
#  'Angry Lobster',
#  'Argentinian Pizza',
#  'Asian appetizers',
#  'Barbecued codfish',
#  'Bartender',
#  'Beef Cube on rice',
#  'Blue Fin Torro (Fatty Tuna)',
#  'Blue Point oysters',
#  'Boton Shrimp',
#  'Butter',
#  'Cakebread Cabernet',
#  'Cantonese',
#  'Chicken Teriyaki dish',
#  'Chicken Tikka Masala',
#  'Chicken pad tai',
#  'Chicken with Cashew Nuts',
#  'Chilean Sea Bass',
#  'Christmas dinner',
#  'Crab Croquette apt',
#  'Deep Fried Skewers',
#  'Deliveries',
#  'Delivery service',
#  'Dosa',
#  'FOOD PORTIONS',
#  'FOOD QUALITY',
#  'Fatty Yellow Tail',
#  'Filet Mignon',
#  'Filet Mignon with garlic mash',
#  'Fluke sashimi',
#  'General Tao chicken',
#  'Gnochi',
#  'Godmother pizza',
#  'Godmother pizza (a sort of traditional flat pizza with an olive oil-brushed crust and less tomato sauce than usual)',
#  'Green Curry dish',
# ...

# %%
import random as rn

# %%
rn.choice(target_to_targets['ambiance'])
# Out:
# 'Traditional French decour'

# %%
from bella.contexts import context

# %%
left_context = context(example, 'left')
right_context = context(example, 'right')
print(left_context)
print(right_context)
print(example['target'])
print(example['text'])
print()
print(example)
# Out:
# ['Our agreed favorite is the ']
# [' (usually the waiters are kind enough to split the dish in half so you get to sample both meats).']
# orrechiete with sausage and chicken
# Our agreed favorite is the orrechiete with sausage and chicken (usually the waiters are kind enough to split the dish in half so you get to sample both meats).
#
# Target({'spans': [(27, 62)], 'target_id': 'restaurants_train14580', 'target': 'orrechiete with sausage and chicken', 'text': 'Our agreed favorite is the orrechiete with sausage and chicken (usually the waiters are kind enough to split the dish in half so you get to sample both meats).', 'sentiment': 1, 'sentence_id': 'restaurants_train1458'})

# %%
alt = 'Traditional French decour'
(left_context[0] + alt + right_context[0])[27:52]
# Out:
# 'Traditional French decour'

# %%
start = len(left_context[0])
end = len(alt) + start
print(f'{start} {end}')
# Out:
# 27 52

# %%
a, b = rest_15_train.categories_targets(coarse=True)
c, d = rest_15_train.categories_targets(coarse=False)
# Out:
# RESTAURANT
# SERVICE
# FOOD
# FOOD
# RESTAURANT
# FOOD
# RESTAURANT
# FOOD
# FOOD
# DRINKS
# DRINKS
# RESTAURANT
# SERVICE
# FOOD
# FOOD
# FOOD
# RESTAURANT
# RESTAURANT
# SERVICE
# FOOD
# RESTAURANT
# SERVICE
# AMBIENCE
# FOOD
# FOOD
# FOOD
# FOOD
# FOOD
# FOOD
# AMBIENCE
# AMBIENCE
# AMBIENCE
# DRINKS
# FOOD
# FOOD
# SERVICE
# RESTAURANT
# RESTAURANT
# FOOD
# SERVICE
# AMBIENCE
# RESTAURANT
# FOOD
# SERVICE
# SERVICE
# RESTAURANT
# FOOD
# SERVICE
# FOOD
# FOOD
# FOOD
# FOOD
# FOOD
# RESTAURANT
# FOOD
# SERVICE
# FOOD
# FOOD
# FOOD
# FOOD
# FOOD
# FOOD
# FOOD
# FOOD
# FOOD
# FOOD
# FOOD
# FOOD
# FOOD
# SERVICE
# SERVICE
# FOOD
# AMBIENCE
# LOCATION
# SERVICE
# FOOD
# FOOD
# FOOD
# AMBIENCE
# AMBIENCE
# FOOD
# FOOD
# FOOD
# FOOD
# AMBIENCE
# FOOD
# FOOD
# FOOD
# FOOD
# FOOD
# FOOD
# FOOD
# FOOD
# FOOD
# FOOD
# DRINKS
# FOOD
# FOOD
# FOOD
# FOOD
# FOOD
# FOOD
# RESTAURANT
# RESTAURANT
# RESTAURANT
# FOOD
# FOOD
# SERVICE
# RESTAURANT
# RESTAURANT
# AMBIENCE
# FOOD
# AMBIENCE
# FOOD
# ...

# %%
c
# Out:
# {'RESTAURANT#GENERAL': ['Patis',
#   "Bloom's",
#   "Rao's",
#   'Emilio',
#   'pink pony',
#   'Jekyll and Hyde Pub',
#   'Mermaid Inn',
#   'joint',
#   'Lucky Strike',
#   'Shabu-Shabu Restaurant',
#   'trattoria',
#   'Casimir',
#   'Zucchero Pomodori',
#   'Myagi',
#   'Faan',
#   'pizzeria',
#   'Saul',
#   'Cafe Noir',
#   'Ginger House',
#   'Gnocchi',
#   'mare',
#   'Pastis',
#   'PLACE',
#   'Amma',
#   'Heartland Brewery',
#   'Fish',
#   'fresh restaurant',
#   'Big Wong',
#   'Rao',
#   'Jekyll and hyde Pub',
#   'spot',
#   'place',
#   'Prune',
#   "Roth's",
#   'Mizu',
#   'Jekyll and Hyde',
#   'Red Eye Grill',
#   'pizza place',
#   'restaurant',
#   'Cafe Spice',
#   'Jeckll and Hydes',
#   'PIZZA 33',
#   'Areo',
#   'Restaurant Saul',
#   'Red Eye',
#   'Planet Thai',
#   'Williamsburg spot',
#   'Chinese restaurant',
#   'Planet Thailand',
#   'Leon',
#   'YUKA',
#   'Teodora',
#   'Pizza 33',
#   'Haru on Park S',
#   'Suan',
#   'Corona',
# ...

# %%
a
# Out:
# {'RESTAURANT': ['Pizza 33',
#   'Planet Thai',
#   'Heartland Brewery',
#   'Jekyll and hyde Pub',
#   'Amma',
#   'Haru on Park S',
#   'restaurant',
#   'Red Eye',
#   "Roth's",
#   'PLACE',
#   'signs',
#   'Gnocchi',
#   'pizza place',
#   'joint',
#   'crowd',
#   'Teodora',
#   'Williamsburg spot',
#   'Suan',
#   'Rao',
#   "Baluchi's",
#   'Chennai Garden',
#   'Lucky Strike',
#   'Fish',
#   'spot',
#   'fresh restaurant',
#   'trattoria',
#   'Big Wong',
#   'YUKA',
#   'mare',
#   'Planet Thailand',
#   'Ginger House',
#   'Thai restaurant',
#   'Areo',
#   'place',
#   'Leon',
#   'Mizu',
#   'Cafe Spice',
#   'Jekyll and Hyde',
#   'Jeckll and Hydes',
#   'staff',
#   "VT's",
#   'Pastis',
#   "Rao's",
#   'Red Eye Grill',
#   'Saul',
#   'Cafe Noir',
#   'PIZZA 33',
#   'Faan',
#   'Shabu-Shabu Restaurant',
#   'Chinese restaurant',
#   'Corona',
#   'Jekyll and Hyde Pub',
#   'pink pony',
#   'Myagi',
#   "Bloom's",
#   'Restaurant Saul',
#   'Zucchero Pomodori',
# ...

# %%
from collections import defaultdict
temp_category_targets = defaultdict(set)
for data in rest_15_train.data():
    category = data['category']
    target = data['target']
    temp_category_targets[category].add(target)
category_targets = {}
for category, targets in temp_category_targets.items():
    category_targets[category] = list(targets)

# %%
category_targets
# Out:
# {'RESTAURANT#GENERAL': ['Cafe Noir',
#   'pizza place',
#   'Amma',
#   'PIZZA 33',
#   'Casimir',
#   'Myagi',
#   'Patis',
#   'Red Eye Grill',
#   'Rao',
#   'Shabu-Shabu Restaurant',
#   'Planet Thailand',
#   'Leon',
#   'joint',
#   'Gnocchi',
#   'Jekyll and Hyde',
#   "Rao's",
#   'Red Eye',
#   'Restaurant Saul',
#   'pizzeria',
#   'Suan',
#   'Chinese restaurant',
#   "Roth's",
#   'Planet Thai',
#   'Saul',
#   'PLACE',
#   'Big Wong',
#   'Jeckll and Hydes',
#   'spot',
#   'Haru on Park S',
#   'Faan',
#   'Heartland Brewery',
#   'Ginger House',
#   'Mizu',
#   'Pizza 33',
#   'Areo',
#   'Prune',
#   'Williamsburg spot',
#   'Zucchero Pomodori',
#   "Bloom's",
#   'Emilio',
#   'Lucky Strike',
#   'Pastis',
#   'Jekyll and hyde Pub',
#   'mare',
#   'pink pony',
#   'Fish',
#   'restaurant',
#   'Jekyll and Hyde Pub',
#   'Corona',
#   'Mermaid Inn',
#   'place',
#   'Chennai Garden',
#   'YUKA',
#   'Cafe Spice',
#   'Teodora',
#   'fresh restaurant',
# ...

# %%
rest_15_id_text = {}
rest_14_id_text = {}
rest_15_sent = {}
for a_id, data in rest_15_train.items():
    rest_15_id_text[a_id] = data['text'].lower().strip()
    rest_15_sent[a_id] = data['sentence_id']
for a_id, data in rest_test.items():
    rest_14_id_text[a_id] = data['text'].lower().strip()

# %%
rest_15_sent['ABSA-15_Restaurants_Train_Final1253117:20']
# Out:
# 'ABSA-15_Restaurants_Train_Final1253117:2'

# %%
len(rest_15_id_text)
# Out:
# 1279

# %%
ids_to_remove = set()
same = set()
for b_id, text in rest_14_id_text.items():
    for a_id, text_1 in rest_15_id_text.items():
        if text == text_1:
            ids_to_remove.add(a_id)
            same.add(b_id)

# %%
ids_to_remove
# Out:
# {'ABSA-15_Restaurants_Train_Final1253117:20',
#  'ABSA-15_Restaurants_Train_Final397331:10',
#  'ABSA-15_Restaurants_Train_Final397331:11'}

# %%
same
# Out:
# {'restaurants_test11350142#1253117#20',
#  'restaurants_test11350142#1253117#21',
#  'restaurants_test11350142#1253117#22',
#  'restaurants_test11478791#397331#10',
#  'restaurants_test11478791#397331#11'}

# %%
ids_to_remove
# Out:
# {'ABSA-15_Restaurants_Train_Final1253117:20',
#  'ABSA-15_Restaurants_Train_Final397331:10',
#  'ABSA-15_Restaurants_Train_Final397331:11'}

# %%
same
# Out:
# {'restaurants_test11350142#1253117#20',
#  'restaurants_test11350142#1253117#21',
#  'restaurants_test11350142#1253117#22',
#  'restaurants_test11478791#397331#10',
#  'restaurants_test11478791#397331#11'}
